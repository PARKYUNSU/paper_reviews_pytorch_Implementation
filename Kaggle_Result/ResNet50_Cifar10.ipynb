# %%
# !python '/kaggle/input/snnt/pytorch/default/1/SE-Net/main.py' --model resnet50
# Out:
# ...
# 100%|███████████████████████| 170498071/170498071 [00:03<00:00, 49110780.79it/s]
# Extracting /kaggle/working/data/cifar-10-python.tar.gz to /kaggle/working/data
# Files already downloaded and verified
# 50000
# 10000
# Epoch 1/100
# 100%|███████████████████████████████████████| 1563/1563 [06:12<00:00,  4.19it/s]
# Train Loss: 2.0744, Train Accuracy: 23.79%, Train Error Rate: 76.21%
# Val Loss: 1.9406, Top-1 Error Rate: 66.19%, Top-5 Error Rate: 12.73%
# Epoch 2/100
# 100%|███████████████████████████████████████| 1563/1563 [06:13<00:00,  4.19it/s]
# Train Loss: 1.7577, Train Accuracy: 35.51%, Train Error Rate: 64.49%
# Val Loss: 1.5908, Top-1 Error Rate: 55.44%, Top-5 Error Rate: 8.61%
# Epoch 3/100
# 100%|███████████████████████████████████████| 1563/1563 [06:07<00:00,  4.25it/s]
# Train Loss: 1.6067, Train Accuracy: 41.42%, Train Error Rate: 58.58%
# Val Loss: 1.4777, Top-1 Error Rate: 51.90%, Top-5 Error Rate: 6.90%
# Epoch 4/100
# ...
