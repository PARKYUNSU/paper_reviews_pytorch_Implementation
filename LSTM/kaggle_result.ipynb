# %%
# !git clone https://github.com/PARKYUNSU/LSTM
# Out:
# Cloning into 'LSTM'...
# remote: Enumerating objects: 389, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (101/101), done.
# Receiving objects: 100% (389/389), 204.82 KiB | 6.02 MiB/s, done.
# remote: Total 389 (delta 75), reused 110 (delta 44), pack-reused 244 (from 1)
# Resolving deltas: 100% (195/195), done.

# %%
# !pip uninstall -y torch torchtext
# !pip install torch==2.0.0+cu118 torchtext==0.15.0 --index-url https://download.pytorch.org/whl/cu118 --no-cache-dir --quiet
# Out:
# Found existing installation: torch 2.4.1+cu121
# Uninstalling torch-2.4.1+cu121:
#   Successfully uninstalled torch-2.4.1+cu121
# WARNING: Skipping torchtext as it is not installed.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 246.9 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 286.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 89.0 MB/s eta 0:00:00a 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 97.2 MB/s eta 0:00:00a 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 303.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 2.0.0+cu118 which is incompatible.
# ...

# %%
import torch
import torchtext

print(f"PyTorch version: {torch.__version__}")
print(f"TorchText version: {torchtext.__version__}")
# Out:
# PyTorch version: 2.0.0+cu118
# TorchText version: 0.15.0+cpu

# %%
# !python "/kaggle/working/LSTM/main.py"
# Out:
# ...
# Epoch 1/30
# Train Loss: 0.0209, Accuracy: 0.5878: 100%|█| 668/668 [00:19<00:00, 33.44batch/s
# Train Loss: 0.0209, Train Accuracy: 0.5878
# Validation Loss: 0.0183, Validation Accuracy: 0.7048
# Epoch 2/30
# Train Loss: 0.0166, Accuracy: 0.7431: 100%|█| 668/668 [00:19<00:00, 33.91batch/s
# Train Loss: 0.0166, Train Accuracy: 0.7431
# Validation Loss: 0.0152, Validation Accuracy: 0.7744
# Epoch 3/30
# Train Loss: 0.0145, Accuracy: 0.7858: 100%|█| 668/668 [00:19<00:00, 34.12batch/s
# Train Loss: 0.0145, Train Accuracy: 0.7858
# Validation Loss: 0.0139, Validation Accuracy: 0.7943
# Epoch 4/30
# Train Loss: 0.0131, Accuracy: 0.8118: 100%|█| 668/668 [00:19<00:00, 34.57batch/s
# Train Loss: 0.0131, Train Accuracy: 0.8118
# Validation Loss: 0.0134, Validation Accuracy: 0.7952
# Epoch 5/30
# Train Loss: 0.0123, Accuracy: 0.8256: 100%|█| 668/668 [00:19<00:00, 34.00batch/s
# Train Loss: 0.0123, Train Accuracy: 0.8256
# Validation Loss: 0.0126, Validation Accuracy: 0.8177
# Epoch 6/30
# ...
