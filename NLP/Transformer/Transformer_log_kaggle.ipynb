# %%
# !git clone https://github.com/PARKYUNSU/Transformer
# Out:
# Cloning into 'Transformer'...
# remote: Enumerating objects: 272, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 272 (delta 34), reused 46 (delta 21), pack-reused 211 (from 1)
# Receiving objects: 100% (272/272), 40.93 KiB | 3.15 MiB/s, done.
# Resolving deltas: 100% (158/158), done.

# %%
# !python "/kaggle/working/Transformer/main.py" --num_layers 2 --d_model 128 --num_heads 4 --d_ff 256 --vocab_size 100 \
               --max_seq_len 50 --dropout 0.1 --batch_size 32 --total_samples 1000 \
               --seq_len 10 --lr 1e-3 --epochs 100 --save_fig
# Out:
# Using device: cuda
# Epoch [1/100] - Train Loss: 4.6038, Val Loss: 4.4230
# Epoch [2/100] - Train Loss: 4.2113, Val Loss: 3.9421
# Epoch [3/100] - Train Loss: 3.8638, Val Loss: 3.5724
# Epoch [4/100] - Train Loss: 3.5573, Val Loss: 3.3242
# Epoch [5/100] - Train Loss: 3.1889, Val Loss: 2.6328
# Epoch [6/100] - Train Loss: 2.7681, Val Loss: 2.1315
# Epoch [7/100] - Train Loss: 2.3884, Val Loss: 1.7229
# Epoch [8/100] - Train Loss: 2.0739, Val Loss: 1.4115
# Epoch [9/100] - Train Loss: 1.8694, Val Loss: 1.1050
# Epoch [10/100] - Train Loss: 1.6548, Val Loss: 0.8978
# Epoch [11/100] - Train Loss: 1.5197, Val Loss: 0.7309
# Epoch [12/100] - Train Loss: 1.4198, Val Loss: 0.6870
# Epoch [13/100] - Train Loss: 1.3296, Val Loss: 0.5674
# Epoch [14/100] - Train Loss: 1.2159, Val Loss: 0.5075
# Epoch [15/100] - Train Loss: 1.1629, Val Loss: 0.4544
# Epoch [16/100] - Train Loss: 1.0837, Val Loss: 0.3816
# Epoch [17/100] - Train Loss: 1.0274, Val Loss: 0.3644
# ...
