# %%
# !python '/kaggle/input/123222/pytorch/default/1/main.py' --model se_resnet50
# Out:
# 20943
# 5236
# Epoch 1/100
# 100%|█████████████████████████████████████████| 655/655 [02:10<00:00,  5.03it/s]
# Train Loss: 2.1011, Train Accuracy: 24.55%, Train Error Rate: 75.45%
# Val Loss: 2.0546, Top-1 Error Rate: 73.47%, Top-5 Error Rate: 23.70%
# Epoch 2/100
# 100%|█████████████████████████████████████████| 655/655 [02:08<00:00,  5.09it/s]
# Train Loss: 1.8641, Train Accuracy: 33.98%, Train Error Rate: 66.02%
# Val Loss: 1.8395, Top-1 Error Rate: 64.72%, Top-5 Error Rate: 14.13%
# Epoch 3/100
# 100%|█████████████████████████████████████████| 655/655 [02:08<00:00,  5.09it/s]
# Train Loss: 1.6359, Train Accuracy: 42.29%, Train Error Rate: 57.71%
# Val Loss: 1.5561, Top-1 Error Rate: 53.40%, Top-5 Error Rate: 10.03%
# Epoch 4/100
# 100%|█████████████████████████████████████████| 655/655 [02:09<00:00,  5.07it/s]
# Train Loss: 1.4250, Train Accuracy: 50.07%, Train Error Rate: 49.93%
# Val Loss: 1.4251, Top-1 Error Rate: 48.40%, Top-5 Error Rate: 8.14%
# Epoch 5/100
# ...

# %%
# !python '/kaggle/input/123222/pytorch/default/1/main.py' --model resnet50
# Out:
# 20943
# 5236
# Epoch 1/100
# 100%|█████████████████████████████████████████| 655/655 [01:54<00:00,  5.70it/s]
# Train Loss: 2.2249, Train Accuracy: 22.02%, Train Error Rate: 77.98%
# Val Loss: 2.2063, Top-1 Error Rate: 73.30%, Top-5 Error Rate: 30.52%
# Epoch 2/100
# 100%|█████████████████████████████████████████| 655/655 [01:54<00:00,  5.71it/s]
# Train Loss: 1.9947, Train Accuracy: 31.33%, Train Error Rate: 68.67%
# Val Loss: 1.8220, Top-1 Error Rate: 61.38%, Top-5 Error Rate: 16.20%
# Epoch 3/100
# 100%|█████████████████████████████████████████| 655/655 [01:54<00:00,  5.71it/s]
# Train Loss: 1.6778, Train Accuracy: 41.67%, Train Error Rate: 58.33%
# Val Loss: 1.5652, Top-1 Error Rate: 54.28%, Top-5 Error Rate: 10.12%
# Epoch 4/100
# 100%|█████████████████████████████████████████| 655/655 [01:54<00:00,  5.72it/s]
# Train Loss: 1.4729, Train Accuracy: 49.18%, Train Error Rate: 50.82%
# Val Loss: 1.5701, Top-1 Error Rate: 51.09%, Top-5 Error Rate: 11.23%
# Epoch 5/100
# ...
