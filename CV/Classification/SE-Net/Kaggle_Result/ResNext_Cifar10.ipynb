# %%
# !python '/kaggle/input/ssssn/pytorch/default/1/SE-Net3/SE-Net/main.py' --model resnext50
# Out:
# ...
# 100%|███████████████████████| 170498071/170498071 [00:05<00:00, 29677858.75it/s]
# Extracting /kaggle/working/data/cifar-10-python.tar.gz to /kaggle/working/data
# Files already downloaded and verified
# 50000
# 10000
# Epoch 1/100
# 100%|███████████████████████████████████████| 1563/1563 [07:03<00:00,  3.69it/s]
# Train Loss: 2.0159, Train Accuracy: 26.05%, Train Error Rate: 73.95%
# Val Loss: 1.7339, Top-1 Error Rate: 61.63%, Top-5 Error Rate: 10.90%
# Epoch 2/100
# 100%|███████████████████████████████████████| 1563/1563 [06:59<00:00,  3.73it/s]
# Train Loss: 1.7026, Train Accuracy: 37.65%, Train Error Rate: 62.35%
# Val Loss: 1.6361, Top-1 Error Rate: 57.34%, Top-5 Error Rate: 8.98%
# Epoch 3/100
# 100%|███████████████████████████████████████| 1563/1563 [06:59<00:00,  3.72it/s]
# Train Loss: 1.5281, Train Accuracy: 44.85%, Train Error Rate: 55.15%
# Val Loss: 1.3415, Top-1 Error Rate: 47.67%, Top-5 Error Rate: 5.44%
# Epoch 4/100
# ...
