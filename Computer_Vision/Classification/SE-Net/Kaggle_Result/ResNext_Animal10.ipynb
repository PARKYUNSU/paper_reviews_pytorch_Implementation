# %%
# !python '/kaggle/input/232323/pytorch/default/1/SE-Net/main.py' --model se_resnext50
# Out:
# 20943
# 5236
# Epoch 1/100
# 100%|█████████████████████████████████████████| 655/655 [03:10<00:00,  3.43it/s]
# Train Loss: 2.1024, Train Accuracy: 24.47%, Train Error Rate: 75.53%
# Val Loss: 1.9611, Top-1 Error Rate: 69.56%, Top-5 Error Rate: 20.17%
# Epoch 2/100
# 100%|█████████████████████████████████████████| 655/655 [03:10<00:00,  3.44it/s]
# Train Loss: 1.8399, Train Accuracy: 34.66%, Train Error Rate: 65.34%
# Val Loss: 1.7151, Top-1 Error Rate: 60.16%, Top-5 Error Rate: 13.24%
# Epoch 3/100
# 100%|█████████████████████████████████████████| 655/655 [03:10<00:00,  3.43it/s]
# Train Loss: 1.5407, Train Accuracy: 46.01%, Train Error Rate: 53.99%
# Val Loss: 1.4766, Top-1 Error Rate: 49.73%, Top-5 Error Rate: 9.38%
# Epoch 4/100
# 100%|█████████████████████████████████████████| 655/655 [03:10<00:00,  3.43it/s]
# Train Loss: 1.3437, Train Accuracy: 53.00%, Train Error Rate: 47.00%
# Val Loss: 1.2781, Top-1 Error Rate: 43.98%, Top-5 Error Rate: 6.26%
# Epoch 5/100
# ...

# %%
# !python '/kaggle/input/232323/pytorch/default/1/SE-Net/main.py' --model resnext50
# Out:
# 20943
# 5236
# Epoch 1/100
# 100%|█████████████████████████████████████████| 655/655 [02:55<00:00,  3.73it/s]
# Train Loss: 2.2200, Train Accuracy: 23.09%, Train Error Rate: 76.91%
# Val Loss: 2.0585, Top-1 Error Rate: 72.08%, Top-5 Error Rate: 21.81%
# Epoch 2/100
# 100%|█████████████████████████████████████████| 655/655 [02:55<00:00,  3.74it/s]
# Train Loss: 1.8983, Train Accuracy: 34.64%, Train Error Rate: 65.36%
# Val Loss: 1.7451, Top-1 Error Rate: 58.65%, Top-5 Error Rate: 13.50%
# Epoch 3/100
# 100%|█████████████████████████████████████████| 655/655 [02:55<00:00,  3.74it/s]
# Train Loss: 1.6161, Train Accuracy: 44.21%, Train Error Rate: 55.79%
# Val Loss: 1.4969, Top-1 Error Rate: 50.92%, Top-5 Error Rate: 9.34%
# Epoch 4/100
# 100%|█████████████████████████████████████████| 655/655 [02:54<00:00,  3.75it/s]
# Train Loss: 1.4106, Train Accuracy: 51.08%, Train Error Rate: 48.92%
# Val Loss: 1.4498, Top-1 Error Rate: 46.08%, Top-5 Error Rate: 8.48%
# Epoch 5/100
# ...
