# %%
# !python '/kaggle/input/senet/pytorch/default/9/SE-Net/main.py' --model se_resnet50
# Out:
# ...
# 100%|███████████████████████| 170498071/170498071 [00:06<00:00, 28233386.69it/s]
# Extracting /kaggle/working/data/cifar-10-python.tar.gz to /kaggle/working/data
# Files already downloaded and verified
# 50000
# 10000
# Epoch 1/100
# 100%|███████████████████████████████████████| 1563/1563 [06:28<00:00,  4.02it/s]
# Train Loss: 2.0017, Train Accuracy: 25.49%, Train Error Rate: 74.51%
# Val Loss: 1.7414, Top-1 Error Rate: 64.33%, Top-5 Error Rate: 12.55%
# Epoch 2/100
# 100%|███████████████████████████████████████| 1563/1563 [06:30<00:00,  4.01it/s]
# Train Loss: 1.7173, Train Accuracy: 35.86%, Train Error Rate: 64.14%
# Val Loss: 1.5357, Top-1 Error Rate: 57.35%, Top-5 Error Rate: 8.90%
# Epoch 3/100
# 100%|███████████████████████████████████████| 1563/1563 [06:27<00:00,  4.04it/s]
# Train Loss: 1.5505, Train Accuracy: 43.46%, Train Error Rate: 56.54%
# Val Loss: 1.3665, Top-1 Error Rate: 50.51%, Top-5 Error Rate: 5.88%
# Epoch 4/100
# ...
