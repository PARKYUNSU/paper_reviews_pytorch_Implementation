# %%
# !python '/kaggle/input/ssnet/pytorch/default/1/SE-Net/main.py' --model se_resnext50
# Out:
# ...
# 100%|███████████████████████| 170498071/170498071 [00:03<00:00, 48806962.78it/s]
# Extracting /kaggle/working/data/cifar-10-python.tar.gz to /kaggle/working/data
# Files already downloaded and verified
# 50000
# 10000
# Epoch 1/100
# 100%|███████████████████████████████████████| 1563/1563 [07:36<00:00,  3.42it/s]
# Train Loss: 1.9722, Train Accuracy: 26.21%, Train Error Rate: 73.79%
# Val Loss: 1.6958, Top-1 Error Rate: 63.99%, Top-5 Error Rate: 11.43%
# Epoch 2/100
# 100%|███████████████████████████████████████| 1563/1563 [07:35<00:00,  3.43it/s]
# Train Loss: 1.6598, Train Accuracy: 38.72%, Train Error Rate: 61.28%
# Val Loss: 1.4312, Top-1 Error Rate: 52.76%, Top-5 Error Rate: 6.87%
# Epoch 3/100
# 100%|███████████████████████████████████████| 1563/1563 [07:34<00:00,  3.44it/s]
# Train Loss: 1.4858, Train Accuracy: 45.80%, Train Error Rate: 54.20%
# Val Loss: 1.2914, Top-1 Error Rate: 47.43%, Top-5 Error Rate: 5.42%
# Epoch 4/100
# ...
